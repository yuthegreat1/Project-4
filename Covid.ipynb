# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
covid = pd.read_csv("Covid Data.csv")
covid.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %%
covid.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
covid['PREGNANT'].unique()
# Out:
# array([ 2, 97, 98,  1], dtype=int64)

# %%
covid['PATIENT_TYPE'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
covid = covid.drop(['CLASIFFICATION_FINAL', 'USMER', 'MEDICAL_UNIT'], axis=1)
covid
# Out:
#          SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  AGE  PREGNANT  \
# 0          1             1  03/05/2020       97          1   65         2
# 1          2             1  03/06/2020       97          1   72        97
# 2          2             2  09/06/2020        1          2   55        97
# 3          1             1  12/06/2020       97          2   53         2
# 4          2             1  21/06/2020       97          2   68        97
# ...      ...           ...         ...      ...        ...  ...       ...
# 1048570    2             1  9999-99-99       97          2   40        97
# 1048571    2             2  9999-99-99        2          2   51        97
# 1048572    2             1  9999-99-99       97          2   55        97
# 1048573    2             1  9999-99-99       97          2   28        97
# 1048574    2             1  9999-99-99       97          2   52        97
#
#          DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %%
covid.loc[covid["DATE_DIED"] == "9999-99-99", "DATE_DIED"] = 0
covid
# Out:
#          SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  AGE  PREGNANT  \
# 0          1             1  03/05/2020       97          1   65         2
# 1          2             1  03/06/2020       97          1   72        97
# 2          2             2  09/06/2020        1          2   55        97
# 3          1             1  12/06/2020       97          2   53         2
# 4          2             1  21/06/2020       97          2   68        97
# ...      ...           ...         ...      ...        ...  ...       ...
# 1048570    2             1           0       97          2   40        97
# 1048571    2             2           0        2          2   51        97
# 1048572    2             1           0       97          2   55        97
# 1048573    2             1           0       97          2   28        97
# 1048574    2             1           0       97          2   52        97
#
#          DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %%
covid.loc[covid["DATE_DIED"] != 0, "DATE_DIED"] = 1
covid
# Out:
#          SEX  PATIENT_TYPE DATE_DIED  INTUBED  PNEUMONIA  AGE  PREGNANT  \
# 0          1             1         1       97          1   65         2
# 1          2             1         1       97          1   72        97
# 2          2             2         1        1          2   55        97
# 3          1             1         1       97          2   53         2
# 4          2             1         1       97          2   68        97
# ...      ...           ...       ...      ...        ...  ...       ...
# 1048570    2             1         0       97          2   40        97
# 1048571    2             2         0        2          2   51        97
# 1048572    2             1         0       97          2   55        97
# 1048573    2             1         0       97          2   28        97
# 1048574    2             1         0       97          2   52        97
#
#          DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %%
covid = covid.rename(columns={'DATE_DIED':'DIED', 'INMSUPR':'IMSUPR', 'HIPERTENSION':'HYPERTENSION'})
covid
# Out:
#          SEX  PATIENT_TYPE DIED  INTUBED  PNEUMONIA  AGE  PREGNANT  DIABETES  \
# 0          1             1    1       97          1   65         2         2
# 1          2             1    1       97          1   72        97         2
# 2          2             2    1        1          2   55        97         1
# 3          1             1    1       97          2   53         2         2
# 4          2             1    1       97          2   68        97         1
# ...      ...           ...  ...      ...        ...  ...       ...       ...
# 1048570    2             1    0       97          2   40        97         2
# 1048571    2             2    0        2          2   51        97         2
# 1048572    2             1    0       97          2   55        97         2
# 1048573    2             1    0       97          2   28        97         2
# 1048574    2             1    0       97          2   52        97         2
#
# ...

# %%
covid['SEX'].value_counts()
# Out:
# 1    525064
# 2    523511
# Name: SEX, dtype: int64

# %%
covid['DIED'].value_counts()
# Out:
# 0    971633
# 1     76942
# Name: DIED, dtype: int64

# %%
covid['INTUBED'].value_counts()
# Out:
# 97    848544
# 2     159050
# 1      33656
# 99      7325
# Name: INTUBED, dtype: int64

# %%
covid['PNEUMONIA'].value_counts()
# Out:
# 2     892534
# 1     140038
# 99     16003
# Name: PNEUMONIA, dtype: int64

# %%
covid['DIABETES'].value_counts()
# Out:
# 2     920248
# 1     124989
# 98      3338
# Name: DIABETES, dtype: int64

# %%
covid['PREGNANT'].value_counts()
# Out:
# 97    523511
# 2     513179
# 1       8131
# 98      3754
# Name: PREGNANT, dtype: int64

# %%
covid['COPD'].value_counts()
# Out:
# 2     1030510
# 1       15062
# 98       3003
# Name: COPD, dtype: int64

# %%
covid['ASTHMA'].value_counts()
# Out:
# 2     1014024
# 1       31572
# 98       2979
# Name: ASTHMA, dtype: int64

# %%
covid['IMSUPR'].value_counts()
# Out:
# 2     1031001
# 1       14170
# 98       3404
# Name: IMSUPR, dtype: int64

# %%
covid['HYPERTENSION'].value_counts()
# Out:
# 2     882742
# 1     162729
# 98      3104
# Name: HYPERTENSION, dtype: int64

# %%
covid['OTHER_DISEASE'].value_counts()
# Out:
# 2     1015490
# 1       28040
# 98       5045
# Name: OTHER_DISEASE, dtype: int64

# %%
covid['CARDIOVASCULAR'].value_counts()
# Out:
# 2     1024730
# 1       20769
# 98       3076
# Name: CARDIOVASCULAR, dtype: int64

# %%
covid['OBESITY'].value_counts()
# Out:
# 2     885727
# 1     159816
# 98      3032
# Name: OBESITY, dtype: int64

# %%
covid['RENAL_CHRONIC'].value_counts()
# Out:
# 2     1026665
# 1       18904
# 98       3006
# Name: RENAL_CHRONIC, dtype: int64

# %%
covid['TOBACCO'].value_counts()
# Out:
# 2     960979
# 1      84376
# 98      3220
# Name: TOBACCO, dtype: int64

# %%
covid['ICU'].value_counts()
# Out:
# 97    848544
# 2     175685
# 1      16858
# 99      7488
# Name: ICU, dtype: int64

# %%
replace98 = covid.replace(98, np.nan)
replace98
# Out:
#          SEX  PATIENT_TYPE  DIED  INTUBED  PNEUMONIA   AGE  PREGNANT  \
# 0          1             1     1       97          1  65.0       2.0
# 1          2             1     1       97          1  72.0      97.0
# 2          2             2     1        1          2  55.0      97.0
# 3          1             1     1       97          2  53.0       2.0
# 4          2             1     1       97          2  68.0      97.0
# ...      ...           ...   ...      ...        ...   ...       ...
# 1048570    2             1     0       97          2  40.0      97.0
# 1048571    2             2     0        2          2  51.0      97.0
# 1048572    2             1     0       97          2  55.0      97.0
# 1048573    2             1     0       97          2  28.0      97.0
# 1048574    2             1     0       97          2  52.0      97.0
#
#          DIABETES  COPD  ASTHMA  IMSUPR  HYPERTENSION  OTHER_DISEASE  \
# ...

# %%
replace99 = replace98.replace(99, np.nan)
replace99
# Out:
#          SEX  PATIENT_TYPE  DIED  INTUBED  PNEUMONIA   AGE  PREGNANT  \
# 0          1             1     1     97.0        1.0  65.0       2.0
# 1          2             1     1     97.0        1.0  72.0      97.0
# 2          2             2     1      1.0        2.0  55.0      97.0
# 3          1             1     1     97.0        2.0  53.0       2.0
# 4          2             1     1     97.0        2.0  68.0      97.0
# ...      ...           ...   ...      ...        ...   ...       ...
# 1048570    2             1     0     97.0        2.0  40.0      97.0
# 1048571    2             2     0      2.0        2.0  51.0      97.0
# 1048572    2             1     0     97.0        2.0  55.0      97.0
# 1048573    2             1     0     97.0        2.0  28.0      97.0
# 1048574    2             1     0     97.0        2.0  52.0      97.0
#
#          DIABETES  COPD  ASTHMA  IMSUPR  HYPERTENSION  OTHER_DISEASE  \
# ...

# %%
dropped = replace99.dropna()
dropped
# Out:
#          SEX  PATIENT_TYPE  DIED  INTUBED  PNEUMONIA   AGE  PREGNANT  \
# 0          1             1     1     97.0        1.0  65.0       2.0
# 1          2             1     1     97.0        1.0  72.0      97.0
# 2          2             2     1      1.0        2.0  55.0      97.0
# 3          1             1     1     97.0        2.0  53.0       2.0
# 4          2             1     1     97.0        2.0  68.0      97.0
# ...      ...           ...   ...      ...        ...   ...       ...
# 1048570    2             1     0     97.0        2.0  40.0      97.0
# 1048571    2             2     0      2.0        2.0  51.0      97.0
# 1048572    2             1     0     97.0        2.0  55.0      97.0
# 1048573    2             1     0     97.0        2.0  28.0      97.0
# 1048574    2             1     0     97.0        2.0  52.0      97.0
#
#          DIABETES  COPD  ASTHMA  IMSUPR  HYPERTENSION  OTHER_DISEASE  \
# ...

# %%
dropped.dtypes
# Out:
# SEX                 int64
# PATIENT_TYPE        int64
# DIED                int64
# INTUBED           float64
# PNEUMONIA         float64
# AGE               float64
# PREGNANT          float64
# DIABETES          float64
# COPD              float64
# ASTHMA            float64
# IMSUPR            float64
# HYPERTENSION      float64
# OTHER_DISEASE     float64
# CARDIOVASCULAR    float64
# OBESITY           float64
# RENAL_CHRONIC     float64
# TOBACCO           float64
# ICU               float64
# dtype: object

# %%
covid = dropped.replace(97, np.nan)
covid
# Out:
#          SEX  PATIENT_TYPE  DIED  INTUBED  PNEUMONIA   AGE  PREGNANT  \
# 0          1             1     1      NaN        1.0  65.0       2.0
# 1          2             1     1      NaN        1.0  72.0       NaN
# 2          2             2     1      1.0        2.0  55.0       NaN
# 3          1             1     1      NaN        2.0  53.0       2.0
# 4          2             1     1      NaN        2.0  68.0       NaN
# ...      ...           ...   ...      ...        ...   ...       ...
# 1048570    2             1     0      NaN        2.0  40.0       NaN
# 1048571    2             2     0      2.0        2.0  51.0       NaN
# 1048572    2             1     0      NaN        2.0  55.0       NaN
# 1048573    2             1     0      NaN        2.0  28.0       NaN
# 1048574    2             1     0      NaN        2.0  52.0       NaN
#
#          DIABETES  COPD  ASTHMA  IMSUPR  HYPERTENSION  OTHER_DISEASE  \
# ...

# %%
covid = covid.drop(['INTUBED', 'ICU', 'PREGNANT'], axis=1)
covid
# Out:
#          SEX  PATIENT_TYPE  DIED  PNEUMONIA   AGE  DIABETES  COPD  ASTHMA  \
# 0          1             1     1        1.0  65.0       2.0   2.0     2.0
# 1          2             1     1        1.0  72.0       2.0   2.0     2.0
# 2          2             2     1        2.0  55.0       1.0   2.0     2.0
# 3          1             1     1        2.0  53.0       2.0   2.0     2.0
# 4          2             1     1        2.0  68.0       1.0   2.0     2.0
# ...      ...           ...   ...        ...   ...       ...   ...     ...
# 1048570    2             1     0        2.0  40.0       2.0   2.0     2.0
# 1048571    2             2     0        2.0  51.0       2.0   2.0     2.0
# 1048572    2             1     0        2.0  55.0       2.0   2.0     2.0
# 1048573    2             1     0        2.0  28.0       2.0   2.0     2.0
# 1048574    2             1     0        2.0  52.0       2.0   2.0     2.0
#
#          IMSUPR  HYPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  \
# ...

# %%
Covid_final = covid.dropna()
Covid_final
# Out:
#          SEX  PATIENT_TYPE  DIED  PNEUMONIA   AGE  DIABETES  COPD  ASTHMA  \
# 0          1             1     1        1.0  65.0       2.0   2.0     2.0
# 1          2             1     1        1.0  72.0       2.0   2.0     2.0
# 2          2             2     1        2.0  55.0       1.0   2.0     2.0
# 3          1             1     1        2.0  53.0       2.0   2.0     2.0
# 4          2             1     1        2.0  68.0       1.0   2.0     2.0
# ...      ...           ...   ...        ...   ...       ...   ...     ...
# 1048570    2             1     0        2.0  40.0       2.0   2.0     2.0
# 1048571    2             2     0        2.0  51.0       2.0   2.0     2.0
# 1048572    2             1     0        2.0  55.0       2.0   2.0     2.0
# 1048573    2             1     0        2.0  28.0       2.0   2.0     2.0
# 1048574    2             1     0        2.0  52.0       2.0   2.0     2.0
#
#          IMSUPR  HYPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  \
# ...

# %%
Covid_final['SEX'].value_counts()
# Out:
# 2    510456
# 1    508889
# Name: SEX, dtype: int64

# %%
Covid_final['DIED'].value_counts()
# Out:
# 0    946215
# 1     73258
# Name: DIED, dtype: int64

# %%
Covid_final['PNEUMONIA'].value_counts()
# Out:
# 2.0    883125
# 1.0    136348
# Name: PNEUMONIA, dtype: int64

# %%
Covid_final['DIABETES'].value_counts()
# Out:
# 2.0    897976
# 1.0    121497
# Name: DIABETES, dtype: int64

# %%
Covid_final['COPD'].value_counts()
# Out:
# 2.0    1005242
# 1.0      14231
# Name: COPD, dtype: int64

# %%
Covid_final['ASTHMA'].value_counts()
# Out:
# 2.0    989144
# 1.0     30329
# Name: ASTHMA, dtype: int64

# %%
Covid_final['IMSUPR'].value_counts()
# Out:
# 2.0    1005956
# 1.0      13517
# Name: IMSUPR, dtype: int64

# %%
Covid_final['HYPERTENSION'].value_counts()
# Out:
# 2.0    861084
# 1.0    158389
# Name: HYPERTENSION, dtype: int64

# %%
Covid_final['OTHER_DISEASE'].value_counts()
# Out:
# 2.0    992495
# 1.0     26978
# Name: OTHER_DISEASE, dtype: int64

# %%
Covid_final['CARDIOVASCULAR'].value_counts()
# Out:
# 2.0    999505
# 1.0     19968
# Name: CARDIOVASCULAR, dtype: int64

# %%
Covid_final['OBESITY'].value_counts()
# Out:
# 2.0    863313
# 1.0    156032
# Name: OBESITY, dtype: int64

# %%
Covid_final['RENAL_CHRONIC'].value_counts()
# Out:
# 2.0    1001140
# 1.0      18205
# Name: RENAL_CHRONIC, dtype: int64

# %%
Covid_final['TOBACCO'].value_counts()
# Out:
# 2.0    937010
# 1.0     82335
# Name: TOBACCO, dtype: int64

# %%
Covid_final['PATIENT_TYPE'].value_counts()
# Out:
# 1    830233
# 2    189112
# Name: PATIENT_TYPE, dtype: int64

# %%
Covid_final.to_csv('Cleaned_Covid.csv')
